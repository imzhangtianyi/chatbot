# %%
import pandas as pd
import re
df_t = pd.read_csv('transcript_all.csv')
df_p = pd.read_csv('product_all.csv')
df_c = df_t.groupby('chat_id').text.apply(' '.join)

# Tokenize chats
from nltk.tokenize import RegexpTokenizer
tokenizer = RegexpTokenizer(r'\w+')

txt = df_c.apply(lambda s: tokenizer.tokenize(s.lower()))

# NLTK Stop words
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
stop_words.extend(['help', 'headout', 'hi', 'hello', 'hey', 'welcome', 'stepping', 'away', 'customers', 'bye', 'problem', 'feel', 'free', 'reach', 'need', 'assistance', 'would', 'nice', 'talk', 'great', 'day', 'goodbye', 'give', 'minutes', 'like', 'assist', 'anything', 'else', 'today', 'thank', 'check', 'please', 'ok','get', 'yes', 'safari', 'khalifa', 'burj', 'aquarium', 'roman', 'palatin', 'vatican', 'dubai'])
def remove_stopwords(l):
    return [word for word in l if word not in stop_words]

t_s = list(map(remove_stopwords,txt))

from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer

porter_stemmer = PorterStemmer()
def stem_words(l):
    return [porter_stemmer.stem(words) for words in l]

stem_list = list(map(stem_words,t_s))

wordnet_lemmatizer = WordNetLemmatizer()
def lemmatize_words(l):
    return [wordnet_lemmatizer.lemmatize(words) for words in l]

lemma_list = list(map(lemmatize_words,stem_list))

# %%
import gensim

id2word = gensim.corpora.Dictionary(lemma_list)
corpus = [id2word.doc2bow(text) for text in lemma_list]
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=20, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)
# Out:
# /home/tianyi/anaconda3/envs/insight/lib/python3.7/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# /home/tianyi/anaconda3/envs/insight/lib/python3.7/site-packages/gensim/models/ldamodel.py:1077: DeprecationWarning: Calling np.sum(generator) is deprecated, and in the future will give a different result. Use np.sum(np.from_iter(generator)) or the python sum builtin instead.
#   score += np.sum(cnt * logsumexp(Elogthetad + Elogbeta[:, int(id)]) for id, cnt in doc)
# ...

# %%
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(lda_model, corpus, id2word)
vis
# Out:
# /home/tianyi/anaconda3/envs/insight/lib/python3.7/site-packages/pyLDAvis/_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return pd.concat([default_term_info] + list(topic_dfs))
# PreparedData(topic_coordinates=              x         y  topics  cluster      Freq
# topic
# 5      0.137750 -0.091896       1        1  9.558339
# 15     0.101609  0.149575       2        1  7.598840
# 2     -0.014498  0.123485       3        1  7.454233
# 14     0.225736  0.051314       4        1  6.306348
# 9      0.170604  0.063172       5        1  6.114202
# 12     0.131016 -0.047204       6        1  6.085956
# 3     -0.141602  0.102605       7        1  5.343399
# 6      0.159332  0.088771       8        1  5.181320
# ...

# %%
def format_topics_sentences(ldamodel, corpus, texts):
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row in enumerate(ldamodel[corpus]):
        row = sorted(row[0], key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

    # Add original text to the end of the output
    contents = pd.Series(texts).reset_index(drop=True)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)


df_topic_sents_keywords = format_topics_sentences(lda_model, corpus, df_c)

# Format
df_topic = df_topic_sents_keywords.reset_index()
df_topic.columns = ['document_no', 'topic_no', 'perc_contrib', 'keywords', 'text']

# Show
df_topic.head(10)
# Out:
#    document_no  topic_no  perc_contrib  \
# 0            0       1.0        0.5722
# 1            1       1.0        0.5722
# 2            2       1.0        0.5723
# 3            3       1.0        0.5722
# 4            4      11.0        0.3703
# 5            5      14.0        0.7646
# 6            6      12.0        0.3484
# 7            7       7.0        0.8581
# 8            8      15.0        0.3831
# 9            9       2.0        0.2844
#
#                                             keywords  \
# 0  pas, week, 1, experi, e, day, 2, attract, may,...
# 1  pas, week, 1, experi, e, day, 2, attract, may,...
# 2  pas, week, 1, experi, e, day, 2, attract, may,...
# 3  pas, week, 1, experi, e, day, 2, attract, may,...
# 4  child, adult, 3, 2, year, ticket, kid, 5, old,...
# 5  avail, book, date, look, ticket, select, month...
# 6  sorri, u, thank, assur, show, wait, contact, u...
# 7  tour, com, http, www, citi, link, packag, unit...
# ...

# %%
df_topic[:1000].groupby('topic_no').first().keywords
# Out:
# topic_no
# 0.0     pick, hotel, stay, transfer, point, drop, loca...
# 1.0     pas, week, 1, experi, e, day, 2, attract, may,...
# 2.0     time, 30, pm, hour, 10, 8, septemb, open, 00, ...
# 3.0     tour, line, guid, skip, colosseum, access, rom...
# 4.0     en, el, por, 12, sagrada, para, lo, se, si, fa...
# 5.0     card, email, reserv, book, receiv, confirm, ma...
# 6.0     discount, price, websit, book, offer, peopl, s...
# 7.0     tour, com, http, www, citi, link, packag, unit...
# 8.0     tri, chat, use, still, error, work, differ, go...
# 9.0     seat, show, select, section, avail, fee, price...
# 10.0    number, cancel, refund, regard, call, book, re...
# 11.0    child, adult, 3, 2, year, ticket, kid, 5, old,...
# 12.0    sorri, u, thank, assur, show, wait, contact, u...
# 13.0    cruis, tower, per, a, eiffel, one, go, summit,...
# 14.0    avail, book, date, look, ticket, select, month...
# 15.0    ticket, buy, purchas, onlin, de, tomorrow, boo...
# ...

# %%
topics = pd.DataFrame(columns=['topic_no', 'topic_name'])

# %%
topics['topic_no'] = [i for i in range(20)]

# %%
topics.at[0,'topic_name'] = 'pick hotel'
topics.at[1,'topic_name'] = 'pass week'
topics.at[2,'topic_name'] = 'time'
topics.at[3,'topic_name'] = 'skip line tour'
topics.at[4,'topic_name'] = 'en el por'
topics.at[5,'topic_name'] = 'reservation'
topics.at[6,'topic_name'] = 'discount offer'
topics.at[7,'topic_name'] = 'tour link'
topics.at[8,'topic_name'] = 'error'
topics.at[9,'topic_name'] = 'select seat'
topics.at[10,'topic_name'] = 'refund'
topics.at[11,'topic_name'] = 'children'
topics.at[12,'topic_name'] = 'sorry'
topics.at[13,'topic_name'] = 'cruise'
topics.at[14,'topic_name'] = 'book a tour'
topics.at[15,'topic_name'] = 'ticket'
topics.at[16,'topic_name'] = 'la realli'
topics.at[17,'topic_name'] = 'museum'
topics.at[18,'topic_name'] = 'promotion offer'
topics.at[19,'topic_name'] = 'cashback'

# %%
topics
# Out:
#     topic_no      topic_name
# 0          0      pick hotel
# 1          1       pass week
# 2          2            time
# 3          3  skip line tour
# 4          4       en el por
# 5          5     reservation
# 6          6  discount offer
# 7          7       tour link
# 8          8           error
# 9          9     select seat
# 10        10          refund
# 11        11    child ticket
# 12        12           sorry
# 13        13          cruise
# 14        14     book a tour
# 15        15          ticket
# 16        16       la realli
# 17        17          museum
# 18        18     coupon code
# 19        19        cashback

# %%
top = pd.DataFrame(columns = ['topic_no', 'topic_name', 'percentage'])

# %%
top = topics.loc[[2,5,6,9,10,11,14,15,18,19]].reset_index(drop=True)

# %%
df_topic.to_csv('df_topic.csv', index=False)

# %%
top.to_csv('top.csv', index=False)

# %%
sum(df_topic.topic_no == 19)/df_topic.shape[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-07ad6d7ebaa8> in <module>()
# ----> 1 sum(df_topic.topic_no == 19)/df_topic.shape[0]
#
# NameError: name 'df_topic' is not defined
